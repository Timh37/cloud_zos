# %%
import numpy as np
import xarray as xr
import dask
import os
import intake
import pandas as pd
from collections import defaultdict
from tqdm.autonotebook import tqdm
from xmip.preprocessing import rename_cmip6, promote_empty_dims, correct_coordinates, broadcast_lonlat, correct_lon, correct_units, fix_metadata,_drop_coords
from xmip.postprocessing import combine_datasets,_concat_sorted_time, match_metrics
from cmip_catalogue_operations import reduce_cat_to_max_num_realizations, reduce_areacello_cat, search_cloud
from cmip_ds_dict_operations import generate_dict_of_datasets, drop_duplicate_timesteps, drop_coords, fix_inconsistent_calendars, find_matching_pic_datasets, store_matched_pic_linfit, subtract_pic_linfit
from cmip_ds_dict_operations import drop_incomplete, drop_vars, create_regridder_dict, subtract_ocean_awMean, get_availability_from_ddicts,select_period, regrid_datasets_in_ddict
import xesmf as xe
import gcsfs
fs = gcsfs.GCSFileSystem() #list stores, stripp zarr from filename, load
# Out:
# /tmp/ipykernel_9439/2348157661.py:8: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# Various functionalities:

# %%
def partial_combined_preprocessing(ds): #'combined_preprocessing' from xmip is problematic for some datasets
    ds = rename_cmip6(ds) # fix naming
    ds = promote_empty_dims(ds) # promote empty dims to actual coordinates
    ds = correct_coordinates(ds) # demote coordinates from data_variables
    ds = broadcast_lonlat(ds) # broadcast lon/lat
    ds = correct_lon(ds) # shift all lons to consistent 0-360
    ds = correct_units(ds) # fix the units
    ''' part of combined preprocessing
    ds = parse_lon_lat_bounds(ds) # rename the `bounds` according to their style (bound or vertex)
    ds = sort_vertex_order(ds) # sort verticies in a consistent manner
    ds = maybe_convert_bounds_to_vertex(ds) # convert vertex into bounds and vice versa, so both are available
    ds = maybe_convert_vertex_to_bounds(ds)
    '''
    ds = fix_metadata(ds)
    ds = ds.drop_vars(_drop_coords, errors="ignore")
    return ds

def cleanup_datasets_in_dict(ddict):
    ddict = drop_duplicate_timesteps(ddict) #remove duplicate timesteps if present
    ddict = drop_coords(ddict,['vertices_latitude','vertices_longitude']) #remove coords & variables
    ddict = drop_vars(ddict,['vertices_latitude','vertices_longitude'])

    ddict_out = defaultdict(dict)
    for k,v in ddict.items():
        
        v = v.isel(dcpp_init_year=0,drop=True,missing_dims='ignore')
        
        if v.source_id=='INM-CM4-8':
            in_russia_blob = ((v.lat>=40)&(v.lat<=70)&(v.lon>=65)&(v.lon<=120))
            in_us_blob = ((v.lat>=40)&(v.lat<=50)&(v.lon>=260)&(v.lon<=290))
            v = v.where(v.lat>=-79).where(in_russia_blob==False).where(in_us_blob==False) 

        if v.source_id=='FGOALS-g3':
            if v.member_id.values in ['r4i1p1f1','r5i1p1f1']:
                print('Large jump between "zos" of FGOALS-g3 from historical to SSP, dropping: '+k)
                continue
                
        if 'x' in v:
            if len(v['x'])==0:
                print('Longitude and/or latitude dimensions have length 0, dropping: '+k)
                continue
        if 'y' in v:
            if len(v['y'])==0:
                print('Longitude and/or latitude dimensions have length 0, dropping: '+k)
                continue
     
        ddict_out[k] = v

    return ddict_out

# %% [markdown]
# Configure the script:

# %%
query_var = 'zos' #variable to use for data query
query_ssps = ['ssp126','ssp245','ssp370','ssp585'] #SSPs to use for data query

ssps_to_process = ['ssp126','ssp245','ssp370','ssp585'] #SSPs to process data for 

regrid = True
target_grid = xr.Dataset(
    {"lat": (["lat"], np.arange(-90, 90, 1), {"units": "degrees_north"}),
     "lon": (["lon"], np.arange(0, 360, 1), {"units": "degrees_east"}),})
target_grid.attrs['name'] = '1x1'

models_to_exclude = ['AWI-CM-1-1-MR','KIOST-ESM'] #models to exclude a-priori becaue of preprocessing/data issues

min_pic_numYears = 150

output_period = ['1980','2500']

output_path = 'gs://leap-persistent/timh37/CMIP6/'

overwrite_existing = False

# %% [markdown]
# Query datasets, tidy up, put into dictionaries of datasets, prepare for preprocessing:

# %%
#search & generate piControl dictionary of datasets
pic_cat = search_cloud(query_var,'piControl','Omon',['source_id', 'member_id','grid_label']) #done separately from hist/SSPs because parent variant (i.e., piControl variant) is not necessarily the same as historical/SSPs variant
pic_ddict = generate_dict_of_datasets(pic_cat,models_to_exclude,partial_combined_preprocessing)
pic_ddict = cleanup_datasets_in_dict(pic_ddict)
pic_ddict = drop_incomplete(pic_ddict) #remove timeseries which are not montonically increasing or have large timegaps (based on checks in CMIP6-LEAP-feadstock)

#search & generate areacello dictionary of datasets
areacello_cat = search_cloud(variable_id='areacello')
areacello_cat = reduce_areacello_cat(areacello_cat) #remove duplicates of model-grid combinations
areacello_ddict = generate_dict_of_datasets(areacello_cat,models_to_exclude,partial_combined_preprocessing)
areacello_ddict = cleanup_datasets_in_dict(areacello_ddict)

for k,v in areacello_ddict.items():
    areacello_ddict[k] = v.isel(member_id=0,drop=True).isel(dcpp_init_year=0,drop=True,missing_dims='ignore') #member_id is irrelevant here and causes issues upon match metrics
    
#search & generate hist+SSPs dictionary of datasets
ssp_cats = defaultdict(dict)
for s,ssp in enumerate(query_ssps):
    cat = search_cloud(query_var,['historical',ssp],'Omon',['source_id', 'member_id','grid_label']) #done per SSP because availability may be different
    ssp_cats[ssp] = cat

#put ssp cats together (AFAIK no other way but to copy an existing catalog and to assign the concatenation of the dataframes inside each separate catalogue as the new dataframe)   
ssp_cats_merged = ssp_cats[query_ssps[0]] 
ssp_cats_merged.esmcat._df = pd.concat([v.df for k,v in ssp_cats.items()],ignore_index=True).drop_duplicates(ignore_index=True)

#remove hist/SSP catalogue entries without areacello and pic source_id/grid_label combinations:
where_no_auxdata = [i for i,val in enumerate(list(ssp_cats_merged.df.source_id+ssp_cats_merged.df.grid_label)) if ( (val in list(areacello_cat.df.source_id+areacello_cat.df.grid_label)) & (val in list(pic_cat.df.source_id+pic_cat.df.grid_label)) ) ]
ssp_cats_merged.esmcat._df = ssp_cats_merged.df.iloc[where_no_auxdata]

ssp_cats_merged = reduce_cat_to_max_num_realizations(ssp_cats_merged) #per model, select grid and 'ipf' combination providing most realizations (needs to be applied to both SSPs together to ensure the same variants are used under both scenarios)

ssp_ddicts = defaultdict(dict) #initialize dictionary to hold ssp dictionaries of datasets
for s,ssp in enumerate(ssps_to_process):
    print(ssp)
    ssp_cat = ssp_cats_merged.search(experiment_id=['historical',ssp],table_id='Omon',variable_id=query_var,require_all_on=['source_id', 'member_id','grid_label']) #retrieve ssp cat from reduced catalogue
    
    ssp_ddict = {}
    ssp_ddict = generate_dict_of_datasets(ssp_cat,models_to_exclude,partial_combined_preprocessing)
    ssp_ddict = cleanup_datasets_in_dict(ssp_ddict)    
    
    with dask.config.set(**{'array.slicing.split_large_chunks': True}): #concatenate historical and SSP
        ssp_ddict = combine_datasets(ssp_ddict,_concat_sorted_time,match_attrs =['source_id', 'grid_label','table_id','variant_label','variable_id'],combine_func_kwargs={'join':'inner','coords':'minimal','compat':'override'})    
    
    ssp_ddict = drop_duplicate_timesteps(ssp_ddict) #remove overlap between historical and ssp experiments, which sometimes exists, again using 'drop_duplicate_timesteps'
    ssp_ddict = fix_inconsistent_calendars(ssp_ddict) #through concatenating hist/SSP, sometimes inconsistencies in time calendar arise
    ssp_ddict = select_period(ssp_ddict,output_period[0],output_period[-1]) #select requested output period
    ssp_ddict = drop_incomplete(ssp_ddict) #remove historical+ssp timeseries which are not montonically increasing or have large timegaps (based on checks in CMIP6-LEAP-feadstock)
    
    ssp_ddict = match_metrics(ssp_ddict,areacello_ddict,['areacello']) #add 'areacello' metric for computing area-weighted mean, if available
    ssp_ddict, datasets_without_pic = find_matching_pic_datasets(ssp_ddict,pic_ddict,query_var,min_pic_numYears) #add matched_pic_ds key to attributes, if available

    ssp_ddict = store_matched_pic_linfit(ssp_ddict,pic_ddict,query_var,os.path.join(output_path,str(query_var)+'_piControl_linfit')) #apply linear fits to matched piControl & store output, if not already stored
    
    ssp_ddicts[ssp] = ssp_ddict #add dictionaries of datasets to dictionary of SSPs

if regrid: #if regridding
    regridder_dict = create_regridder_dict(ssp_ddicts,target_grid) #generate xesmf regridders per model-grid combination  
    #TO-DO: develop option to regrid to tide gauges/list of coordinates
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.zstore.dcpp_init_year.version'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='82' class='' max='82' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [82/82 00:07&lt;00:00]
#     </div>
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MRI.MRI-ESM2-0.piControl.r1i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MRI.MRI-ESM2-0.piControl.r1i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.piControl.r1i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.piControl.r1i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.piControl.r1i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.piControl.r1i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MRI.MRI-ESM2-0.piControl.r1i2p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MRI.MRI-ESM2-0.piControl.r1i2p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.zstore.dcpp_init_year.version'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='64' class='' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [64/64 00:02&lt;00:00]
#     </div>
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Ofx.gn.none.areacello:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Ofx.gn.none.areacello:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: FAFMIP.MIROC.MIROC6.faf-passiveheat.r1i1p1f1.Ofx.gn.none.areacello:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: FAFMIP.MIROC.MIROC6.faf-passiveheat.r1i1p1f1.Ofx.gn.none.areacello:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MRI.MRI-ESM2-0.historical.r4i1p1f1.Ofx.gn.none.areacello:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MRI.MRI-ESM2-0.historical.r4i1p1f1.Ofx.gn.none.areacello:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# ssp126
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.zstore.dcpp_init_year.version'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='622' class='' max='622' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [622/622 00:29&lt;00:00]
#     </div>
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r33i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r33i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r44i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r44i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r11i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r11i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r48i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r48i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r39i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r39i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r8i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r8i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r31i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r31i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r49i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r49i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r25i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r25i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r49i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r49i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r2i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r2i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r22i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r22i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r12i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r12i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r34i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r34i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r38i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r38i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r16i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r16i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r12i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r12i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r36i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r36i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r1i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r1i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r45i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r45i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r15i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r15i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r33i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r33i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r28i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r28i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r43i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r43i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r16i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r16i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r38i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r38i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r34i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r34i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r29i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r29i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r35i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r35i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r24i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r24i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r25i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r25i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r27i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r27i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r30i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r10i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r10i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r30i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r10i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r10i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r44i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r44i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r6i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r6i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r4i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r4i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r24i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r24i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r48i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r48i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r19i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r19i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r6i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r6i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r8i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r8i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r40i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r40i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r32i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r32i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r26i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r26i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r7i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r7i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r32i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r32i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r11i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r11i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r31i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r31i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r27i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r27i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r42i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r42i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r3i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r3i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r26i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r10i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r10i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp126.r26i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r15i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r15i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# ...
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r20i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r20i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r21i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r21i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r9i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r9i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r47i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r47i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r21i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r21i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r40i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r40i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r23i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r23i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r7i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r7i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r9i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r9i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r31i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r31i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r41i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r41i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r50i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r50i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r7i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r7i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r46i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r46i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r37i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r37i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r3i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r3i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r36i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r36i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r5i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: ScenarioMIP.MIROC.MIROC6.ssp585.r5i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r4i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r4i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r14i1p1f1.Omon.gn.none.zos:While renaming to target `lon_bounds`, more than one candidate was found ['x_bnds', 'vertices_longitude']. Renaming x_bnds to lon_bounds. Please double check results.
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xmip/preprocessing.py:96: UserWarning: CMIP.MIROC.MIROC6.historical.r14i1p1f1.Omon.gn.none.zos:While renaming to target `lat_bounds`, more than one candidate was found ['y_bnds', 'vertices_latitude']. Renaming y_bnds to lat_bounds. Please double check results.
#   warnings.warn(
# Dropping duplicate timesteps for:CMIP.E3SM-Project.E3SM-1-0.historical.r5i1p1f1.Omon.zos.gr.gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-0/historical/r5i1p1f1/Omon/zos/gr/v20200429/.20200429
#   0%|          | 0/317 [00:00<?, ?it/s]
#   0%|          | 0/317 [00:00<?, ?it/s]
#   0%|          | 0/41 [00:00<?, ?it/s]

# %% [markdown]
# Carry out preprocessing:

# %%
for s,ssp in enumerate(ssps_to_process):
    print(ssp)
    ssp_ddict = ssp_ddicts[ssp]
    
    ssp_ddict = subtract_pic_linfit(ssp_ddict,query_var,os.path.join(output_path,str(query_var)+'_piControl_linfit')) #correct for drift
    ssp_ddict = subtract_ocean_awMean(ssp_ddict,query_var) #remove ocean area-weighted mean

    if regrid:
        ssp_ddict = regrid_datasets_in_ddict(ssp_ddict,regridder_dict)
    ssp_ddicts[ssp] = ssp_ddict
# Out:
# ssp126
#   0%|          | 0/310 [00:00<?, ?it/s]
#   0%|          | 0/254 [00:00<?, ?it/s]
#   0%|          | 0/254 [00:00<?, ?it/s]
# ssp245
#   0%|          | 0/404 [00:00<?, ?it/s]
#   0%|          | 0/348 [00:00<?, ?it/s]
#   0%|          | 0/348 [00:00<?, ?it/s]
# ssp370
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/233 [00:00<?, ?it/s]
#   0%|          | 0/233 [00:00<?, ?it/s]
# ssp585
#   0%|          | 0/317 [00:00<?, ?it/s]
#   0%|          | 0/260 [00:00<?, ?it/s]
#   0%|          | 0/260 [00:00<?, ?it/s]

# %% [markdown]
# Store output:

# %%
for s,ssp in enumerate(ssps_to_process):
    print(ssp)
    ssp_ddict = ssp_ddicts[ssp]
    
    for key,ds in tqdm(ssp_ddict.items()):
        ds_name = key+'.hist_'+ssp+'.'+str(ds.time[0].dt.year.values)+'-'+str(ds.time[-1].dt.year.values) #generate file name

        output_fn = os.path.join(output_path,query_var+['','_'+target_grid.attrs['name']][regrid],ds.source_id,ds_name)
        
        if overwrite_existing or not fs.exists(output_fn):   
            ds = ds[[query_var]] #get rid of 'area' that is a variable in some datasets
            ds[query_var] = ds[query_var].chunk({'time':200,'member_id':1,'lat':len(target_grid.lat),'lon':len(target_grid.lon)})
            print('storing: '+output_fn)
            ds.to_zarr(output_fn,mode='w') 
            ds.close()
        else:
            #print(output_fn+' already exists in output directory, moving on.')
# Out:
# ssp126
#   0%|          | 0/254 [00:00<?, ?it/s]
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r1i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r46i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r7i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r19i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r9i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r33i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/FIO-ESM-2-0/FIO-ESM-2-0.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r7i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/NorESM2-LM/NorESM2-LM.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r6i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5-CanOE/CanESM5-CanOE.gn.Omon.r2i1p2f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r35i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CAMS-CSM1-0/CAMS-CSM1-0.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2099 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r44i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r1i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r18i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r11i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r48i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r10i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r39i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r4i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r16i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r13i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r9i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r8i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r16i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r10i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r31i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r19i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r4i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r49i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r20i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r41i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r2i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r25i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r37i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r13i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CAS-ESM2-0/CAS-ESM2-0.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/FGOALS-g3/FGOALS-g3.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r39i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# storing: gs://leap-persistent/timh37/CMIP6/zos_1x1/INM-CM4-8/INM-CM4-8.gr1.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg-LR/EC-Earth3-Veg-LR.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r10i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r8i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r1i1p1f3.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5-CanOE/CanESM5-CanOE.gn.Omon.r3i1p2f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CESM2/CESM2.gn.Omon.r10i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg-LR/EC-Earth3-Veg-LR.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r22i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r20i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r19i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r16i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CESM2/CESM2.gn.Omon.r11i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r22i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r5i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r21i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r12i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r40i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r33i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r12i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r30i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r31i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r34i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/NorESM2-MM/NorESM2-MM.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r17i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r50i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-MM/HadGEM3-GC31-MM.gn.Omon.r1i1p1f3.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r47i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r36i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r38i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r23i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r2i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r27i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r16i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r31i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r18i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r32i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r36i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CMCC-CM2-SR5/CMCC-CM2-SR5.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/GFDL-ESM4/GFDL-ESM4.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r17i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r8i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r27i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r45i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r15i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r17i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r30i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r28i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r43i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/INM-CM5-0/INM-CM5-0.gr1.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r21i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r11i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r6i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r11i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r25i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r7i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r8i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-HR/MPI-ESM1-2-HR.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r34i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r29i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r28i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CIESM/CIESM.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r10i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r14i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r23i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r29i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r21i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r35i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r24i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r24i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r48i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r5i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5-CanOE/CanESM5-CanOE.gn.Omon.r1i1p2f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r13i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r3i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r9i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r40i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r38i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r16i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r19i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r8i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r37i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r39i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r27i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r30i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r10i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r22i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r11i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r14i1p1f1.zos.hist_ssp126.1980-2101 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r26i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r7i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1-HR/CNRM-CM6-1-HR.gn.Omon.r1i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r10i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r45i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r1i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CAMS-CSM1-0/CAMS-CSM1-0.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2099 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r35i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r9i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r12i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r2i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r3i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/FGOALS-g3/FGOALS-g3.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r5i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/TaiESM1/TaiESM1.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r33i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r24i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r19i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r49i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r8i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r40i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r32i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r42i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r43i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CMCC-ESM2/CMCC-ESM2.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r26i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r26i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r25i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r9i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r24i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg-LR/EC-Earth3-Veg-LR.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r13i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r12i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r42i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r38i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r5i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r28i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r15i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r14i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r20i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CESM2/CESM2.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r3i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r18i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r23i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r29i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r8i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r14i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r36i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r18i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r9i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r5i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r23i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r32i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r41i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r15i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r14i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r37i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r17i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r50i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r17i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r12i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MRI-ESM2-0/MRI-ESM2-0.gn.Omon.r1i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r13i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r47i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r4i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r34i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r11i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r15i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r9i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r18i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r10i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r3i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r5i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r21i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r44i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r4i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r20i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r9i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r7i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r25i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r5i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r46i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/UKESM1-0-LL/UKESM1-0-LL.gn.Omon.r4i1p1f2.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r6i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r2i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r5i1p1f2.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r11i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r7i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r15i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r22i1p1f1.zos.hist_ssp126.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r14i1p1f1.zos.hist_ssp126.1980-2100 already exists in output directory, moving on.
# ssp245
#   0%|          | 0/348 [00:00<?, ?it/s]
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r7i1p1f2.zos.hist_ssp245.1980-2020 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r6i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r3i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CAMS-CSM1-0/CAMS-CSM1-0.gn.Omon.r2i1p1f1.zos.hist_ssp245.1980-2099 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r37i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r7i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r20i1p1f3.zos.hist_ssp245.1980-2020 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r44i1p1f1.zos.hist_ssp245.1980-2039 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r35i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r46i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/GISS-E2-1-G/GISS-E2-1-G.gn.Omon.r9i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r19i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r18i1p1f3.zos.hist_ssp245.1980-2020 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r16i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r7i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r11i1p1f1.zos.hist_ssp245.1980-2039 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r4i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r27i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r23i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r41i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r48i1p1f1.zos.hist_ssp245.1980-2039 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r5i1p1f3.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-CC/EC-Earth3-CC.gn.Omon.r7i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r8i1p1f1.zos.hist_ssp245.1980-2039 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r10i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/GISS-E2-1-G/GISS-E2-1-G.gn.Omon.r10i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r4i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r31i1p1f1.zos.hist_ssp245.1980-2039 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r54i1p1f3.zos.hist_ssp245.1980-2020 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r25i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r4i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r2i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r34i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r47i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r19i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r19i1p1f3.zos.hist_ssp245.1980-2020 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-CC/EC-Earth3-CC.gn.Omon.r10i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r49i1p1f1.zos.hist_ssp245.1980-2039 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r23i1p1f3.zos.hist_ssp245.1980-2020 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CAS-ESM2-0/CAS-ESM2-0.gn.Omon.r1i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r11i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r1i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/FGOALS-g3/FGOALS-g3.gn.Omon.r4i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r10i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r5i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r1i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r49i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1-HR/CNRM-CM6-1-HR.gn.Omon.r1i1p1f2.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# storing: gs://leap-persistent/timh37/CMIP6/zos_1x1/INM-CM4-8/INM-CM4-8.gr1.Omon.r1i1p1f1.zos.hist_ssp245.1980-2100
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r6i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r7i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r8i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-CC/EC-Earth3-CC.gn.Omon.r13i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r17i1p1f1.zos.hist_ssp245.1980-2100 already exists in output directory, moving on.
# ...
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r4i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r12i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r3i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r2i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r36i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r5i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r5i1p1f1.zos.hist_ssp585.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r7i1p1f1.zos.hist_ssp585.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/E3SM-1-0/E3SM-1-0.gr.Omon.r3i1p1f1.zos.hist_ssp585.1980-2099 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r13i1p1f1.zos.hist_ssp585.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r8i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r2i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r27i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r10i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r6i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/FGOALS-g3/FGOALS-g3.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r18i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r33i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r24i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r13i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r23i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r40i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r4i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg-LR/EC-Earth3-Veg-LR.gn.Omon.r3i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r11i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r35i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r26i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-MM/HadGEM3-GC31-MM.gn.Omon.r3i1p1f3.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r25i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/TaiESM1/TaiESM1.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r26i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r32i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/E3SM-1-0/E3SM-1-0.gr.Omon.r1i1p1f1.zos.hist_ssp585.1980-2099 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MRI-ESM2-0/MRI-ESM2-0.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r36i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r13i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r15i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r28i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r4i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r14i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CESM2/CESM2.gn.Omon.r4i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-CC/EC-Earth3-CC.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r20i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg/EC-Earth3-Veg.gn.Omon.r2i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r14i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC-ES2L/MIROC-ES2L.gn.Omon.r2i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r3i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r13i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r8i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r36i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r10i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r14i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r18i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1/CNRM-CM6-1.gn.Omon.r3i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r2i1p1f3.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r25i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r23i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r15i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-ESM2-1/CNRM-ESM2-1.gn.Omon.r1i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r1i1p1f3.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r22i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r9i1p1f1.zos.hist_ssp585.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r50i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CESM2-FV2/CESM2-FV2.gn.Omon.r1i2p2f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r4i1p1f3.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-LL/HadGEM3-GC31-LL.gn.Omon.r3i1p1f3.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r39i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r47i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/INM-CM5-0/INM-CM5-0.gr1.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r15i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/FIO-ESM-2-0/FIO-ESM-2-0.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r18i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r8i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3-Veg-LR/EC-Earth3-Veg-LR.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r39i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r5i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r41i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/EC-Earth3/EC-Earth3.gn.Omon.r3i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r20i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r9i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/HadGEM3-GC31-MM/HadGEM3-GC31-MM.gn.Omon.r2i1p1f3.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/NorESM2-LM/NorESM2-LM.gn.Omon.r1i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r37i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r2i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r5i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r6i1p1f1.zos.hist_ssp585.1980-2300 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r40i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-ESM1-5/ACCESS-ESM1-5.gn.Omon.r38i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r30i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r3i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r2i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r21i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CNRM-CM6-1-HR/CNRM-CM6-1-HR.gn.Omon.r1i1p1f2.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r9i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r47i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/IPSL-CM6A-LR/IPSL-CM6A-LR.gn.Omon.r6i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CESM2/CESM2.gn.Omon.r11i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MIROC6/MIROC6.gn.Omon.r7i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r41i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/CanESM5/CanESM5.gn.Omon.r24i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/MPI-ESM1-2-LR/MPI-ESM1-2-LR.gn.Omon.r7i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
# gs://leap-persistent/timh37/CMIP6/zos_1x1/ACCESS-CM2/ACCESS-CM2.gn.Omon.r7i1p1f1.zos.hist_ssp585.1980-2100 already exists in output directory, moving on.
